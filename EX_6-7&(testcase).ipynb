# %%
#EX.NO:6A

import numpy as np
from sklearn.linear_model import LinearRegression
x = np.array([5, 15, 25, 35, 45, 55]).reshape((-1, 1))
y = np.array([5, 20, 14, 32, 22, 38])
model = LinearRegression().fit(x, y)
r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)
y_pred = model.predict(x)
print('predicted response:', y_pred)
# Out:
# coefficient of determination: 0.715875613747954
# predicted response: [ 8.33333333 13.73333333 19.13333333 24.53333333 29.93333333 35.33333333]

# %%
#EX>NO:6B

import numpy as np
from sklearn.linear_model import LinearRegression
x = [[0, 1], [5, 1], [15, 2], [25, 5], [35, 11], [45, 15], [55, 34], [60, 35]]
y = [4, 5, 20, 14, 32, 22, 38, 43]
x, y = np.array(x), np.array(y)
model = LinearRegression().fit(x, y)
r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
y_pred = model.predict(x)
print('predicted response:', y_pred)
# Out:
# coefficient of determination: 0.8615939258756776
# intercept: 5.52257927519819
# slope: [0.44706965 0.25502548]
# predicted response: [ 5.77760476  8.012953   12.73867497 17.9744479  23.97529728 29.4660957
#  38.78227633 41.27265006]

# %%
#TEST CASE FOR EX.NO:6
# Simple Linear Regression using sklearn

import numpy as np
from sklearn.linear_model import LinearRegression

# Independent variable
x = np.array([5, 15, 25, 35, 45, 55]).reshape((-1, 1))

# Dependent variable
y = np.array([5, 20, 14, 32, 22, 38])

# Create model
model = LinearRegression()

# Fit model
model.fit(x, y)

# Coefficient of determination (R^2)
r_sq = model.score(x, y)
print('Coefficient of determination:', r_sq)

# Predict response
y_pred = model.predict(x)
print('Predicted response:', y_pred)
# Out:
# Coefficient of determination: 0.715875613747954
# Predicted response: [ 8.33333333 13.73333333 19.13333333 24.53333333 29.93333333 35.33333333]

# %%
#EX.NO:7

import math
import numpy as np
from numpy.random import randn
from statsmodels.stats.weightstats import ztest

mean_iq = 110
sample_size = 50
population_sd = 15

sd_iq = population_sd / math.sqrt(sample_size)
alpha = 0.05
null_mean = 100

data = sd_iq * randn(sample_size) + mean_iq

print('mean = %.2f stdv = %.2f' % (np.mean(data), np.std(data)))

ztest_score, p_value = ztest(data, value=null_mean, alternative='larger')

print("Z-score = %.4f" % ztest_score)
print("P-value = %.4f" % p_value)

if p_value < alpha:
    print("Reject Null Hypothesis")
else:
    print("Fail to Reject Null Hypothesis")
# Out:
# mean = 109.97 stdv = 1.85
# Z-score = 37.7410
# P-value = 0.0000
# Reject Null Hypothesis
